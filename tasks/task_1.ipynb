# %%
from langchain.prompts import PromptTemplate, ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate

template_v1 = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners"
)
print("Task 1 Output:", template_v1.format(topic="Quantum Computing"))

multi_input_template = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

test_cases = [
    {"topic": "AI", "audience": "beginners", "tone": "friendly"},
    {"topic": "Python", "audience": "kids", "tone": "fun"},
    {"topic": "Deep Learning", "audience": "engineers", "tone": "technical"}
]

print("\nTask 2 Outputs:")
for test in test_cases:
    print(multi_input_template.format(**test))


teaching_template = PromptTemplate(input_variables=["topic"], template="Explain {topic} clearly step by step")
interview_template = PromptTemplate(input_variables=["topic"], template="Ask 3 questions about {topic}")
story_template = PromptTemplate(input_variables=["topic"], template="Explain {topic} as a story")

topic_val = "Machine Learning"
print("\nTask 3 Variations:")
print("Teaching:", teaching_template.format(topic=topic_val))
print("Interview:", interview_template.format(topic=topic_val))
print("Storytelling:", story_template.format(topic=topic_val))


    role_behaviors = {
        "teacher": "You are a helpful teacher who explains complex concepts simply.",
        "interviewer": "You are a professional interviewer asking technical questions.",
        "motivator": "You are an inspiring mentor encouraging the student."
    }
    
    system_template = SystemMessagePromptTemplate.from_template(role_behaviors.get(role, "You are a helpful assistant."))
    human_template = HumanMessagePromptTemplate.from_template("{topic}")
    
    chat_template = ChatPromptTemplate.from_messages([system_template, human_template])
    return chat_template.format_prompt(topic=topic).to_messages()

print("\nTask 4 (Chat Example):", get_chat_prompt("teacher", "Neural Networks"))


def validate_inputs(audience, tone):
    valid_audiences = ["beginner", "intermediate", "expert"]
    valid_tones = ["formal", "casual", "fun"]
    
    final_audience = audience if audience in valid_audiences else "beginner"
    final_tone = tone if tone in valid_tones else "formal"
    
    return final_audience, final_tone


def generate_prompt(topic, audience, tone, style):
   
    audience, tone = validate_inputs(audience, tone)
    
    styles = {
        "teaching": "Explain {topic} for {audience} in a {tone} teaching style.",
        "interview": "Generate interview questions about {topic} for an {audience} in a {tone} tone.",
        "storytelling": "Explain {topic} for {audience} in a {tone} storytelling style."
    }
    
    selected_template = PromptTemplate(
        input_variables=["topic", "audience", "tone"],
        template=styles.get(style, styles["teaching"])
    )
    
    return selected_template.format(topic=topic, audience=audience, tone=tone)

print("\nTask 6 Output:", generate_prompt("Neural Networks", "beginner", "fun", "storytelling"))


reusable_temp = PromptTemplate(input_variables=["concept"], template="Define {concept} in one sentence.")
concepts = ["LLM", "RAG", "Tokens", "Hallucination", "Fine-tuning"]

print("\nTask 7 Reusability Test:")
for c in concepts:
    print(reusable_temp.format(concept=c))
